# %% [markdown]
# <a href="https://colab.research.google.com/github/karamii113/Tamrin2/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# تمرین سوم نمودار اول

# %%
x= np.linspace(-5, 5, 500)

# %%
y1= x**3

# %%
plt.plot(x, y1, 'm--')
plt.title('plot of x^3')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# تمرین سوم تابع اول امتیازی

# %%
x= np.linspace(-5, 5, 500)

# %%
y1=x**3

# %%
plt.plot(x, y1, 'm--')
plt.fill_between(x, y, color='pink')
plt.title('plot of x^3')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# تمرین سوم ترکیب تابع دوم و سوم

# %%
x= np.linspace(-5, 5, 500)

# %%
y2= np.cos(1.2 * x)
y3= np.exp(-x**2)

# %%
plt.plot(x, y2, 'g--', label='cos(1.2*x)')
plt.plot(x, y3, 'r', label='exp(-x^2)')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of Mathematical Functions')
plt.legend()
plt.show()
